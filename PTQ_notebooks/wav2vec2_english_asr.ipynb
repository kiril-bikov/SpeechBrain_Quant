# %% [markdown]
# # Post-training quantizatoin of Wav2Vec2 on GPU

# %% [markdown]
# Before we start, let's install both `datasets`,  `transformers` and `librosa`.

# %%
# %%capture
# !pip install datasets==1.18.3
# !pip install transformers==4.17.0
# !pip install jiwer
# !pip install librosa

# %%
device = 'cuda'

# %%
# ! git clone https://github.com/NVIDIA/TensorRT.git

# %%
# ! cd TensorRT/tools/pytorch-quantization && pip install .

# %% [markdown]
# ## Prepare Data, Tokenizer, Feature Extractor

# %% [markdown]
# ASR models transcribe speech to text, which means that we both need a feature extractor that processes the speech signal to the model's input format, *e.g.* a feature vector, and a tokenizer that processes the model's output format to text.
#
# In Transformers, the Wav2Vec2 model is thus accompanied by both a tokenizer, called [Wav2Vec2CTCTokenizer](https://huggingface.co/transformers/master/model_doc/wav2vec2.html#wav2vec2ctctokenizer), and a feature extractor, called [Wav2Vec2FeatureExtractor](https://huggingface.co/transformers/master/model_doc/wav2vec2.html#wav2vec2featureextractor).
#
# Let's start by creating the tokenizer responsible for decoding the model's predictions.

# %% [markdown]
# ### Create Wav2Vec2CTCTokenizer

# %% [markdown]
# Let's start by loading the dataset and taking a look at its structure.

# %%
from datasets import load_dataset, load_metric

timit = load_dataset("timit_asr")
# Out:
# Reusing dataset timit_asr (/home/kmb85/.cache/huggingface/datasets/timit_asr/clean/2.0.1/b11b576ddcccbcefa7c9f0c4e6c2a43756f3033adffe0fb686aa61043d0450ad)
#   0%|          | 0/2 [00:00<?, ?it/s]

# %%
timit
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['file', 'audio', 'text', 'phonetic_detail', 'word_detail', 'dialect_region', 'sentence_type', 'speaker_id', 'id'],
#         num_rows: 4620
#     })
#     test: Dataset({
#         features: ['file', 'audio', 'text', 'phonetic_detail', 'word_detail', 'dialect_region', 'sentence_type', 'speaker_id', 'id'],
#         num_rows: 1680
#     })
# })

# %%
timit = timit.remove_columns(["phonetic_detail", "word_detail", "dialect_region", "id", "sentence_type", "speaker_id"])

# %% [markdown]
# We normalize the text to only have lower case letters and append a word separator token at the end.

# %%
import re
chars_to_ignore_regex = '[\,\?\.\!\-\;\:\"]'

def remove_special_characters(batch):
    batch["text"] = re.sub(chars_to_ignore_regex, '', batch["text"]).lower() + " "
    return batch

# %%
timit = timit.map(remove_special_characters)
# Out:
# Parameter 'function'=<function remove_special_characters at 0x7ff2ac56dc60> of the transform datasets.arrow_dataset.Dataset._map_single couldn't be hashed properly, a random hash was used instead. Make sure your transforms and parameters are serializable with pickle or dill for the dataset fingerprinting and caching to work. If you reuse this transform, the caching mechanism will consider it to be different from the previous calls and recompute everything. This warning is only showed once. Subsequent hashing failures won't be showed.
# 0ex [00:00, ?ex/s]
# 0ex [00:00, ?ex/s]

# %% [markdown]
# We write a mapping function that concatenates all transcriptions into one long transcription and then transforms the string into a set of chars.
# It is important to pass the argument `batched=True` to the `map(...)` function so that the mapping function has access to all transcriptions at once.

# %%
def extract_all_chars(batch):
  all_text = " ".join(batch["text"])
  vocab = list(set(all_text))
  return {"vocab": [vocab], "all_text": [all_text]}

# %%
vocabs = timit.map(extract_all_chars, batched=True, batch_size=-1, keep_in_memory=True, remove_columns=timit.column_names["train"])
# Out:
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]

# %% [markdown]
# Now, we create the union of all distinct letters in the training dataset and test dataset and convert the resulting list into an enumerated dictionary.

# %%
vocab_list = list(set(vocabs["train"]["vocab"][0]) | set(vocabs["test"]["vocab"][0]))

# %%
vocab_dict = {v: k for k, v in enumerate(vocab_list)}
vocab_dict
# Out:
# {'z': 0,
#  'c': 1,
#  'r': 2,
#  'g': 3,
#  'n': 4,
#  't': 5,
#  'p': 6,
#  'a': 7,
#  's': 8,
#  'o': 9,
#  'f': 10,
#  'i': 11,
#  'h': 12,
#  'k': 13,
#  'm': 14,
#  'w': 15,
#  'j': 16,
#  "'": 17,
#  ' ': 18,
#  'u': 19,
#  'b': 20,
#  'x': 21,
#  'd': 22,
#  'v': 23,
#  'q': 24,
#  'y': 25,
#  'e': 26,
#  'l': 27}

# %% [markdown]
# Finally, we also add a padding token that corresponds to CTC's "*blank token*". The "blank token" is a core component of the CTC algorithm. For more information, please take a look at the "Alignment" section [here](https://distill.pub/2017/ctc/).

# %%
vocab_dict["|"] = vocab_dict[" "]
del vocab_dict[" "]

# %%
vocab_dict["[UNK]"] = len(vocab_dict)
vocab_dict["[PAD]"] = len(vocab_dict)
len(vocab_dict)
# Out:
# 30

# %% [markdown]
# Let's now save the vocabulary as a json file.

# %%
import json
with open('vocab.json', 'w') as vocab_file:
    json.dump(vocab_dict, vocab_file)

# %% [markdown]
# In a final step, we use the json file to instantiate an object of the `Wav2Vec2CTCTokenizer` class.

# %%
from transformers import Wav2Vec2CTCTokenizer

tokenizer = Wav2Vec2CTCTokenizer("./vocab.json", unk_token="[UNK]", pad_token="[PAD]", word_delimiter_token="|")

# %% [markdown]
# ### Create Wav2Vec2 Feature Extractor

# %%
from transformers import Wav2Vec2FeatureExtractor

feature_extractor = Wav2Vec2FeatureExtractor(feature_size=1, sampling_rate=16000, padding_value=0.0, do_normalize=True, return_attention_mask=False)

# %%
from transformers import Wav2Vec2Processor

processor = Wav2Vec2Processor(feature_extractor=feature_extractor, tokenizer=tokenizer)

# %% [markdown]
# Next, we can prepare the dataset.

# %% [markdown]
# Let's apply the data preparation function to all examples.

# %%
def prepare_dataset(batch):
    audio = batch["audio"]

    batch["input_values"] = processor(audio["array"], sampling_rate=audio["sampling_rate"]).input_values[0]
    batch["input_length"] = len(batch["input_values"])

    with processor.as_target_processor():
        batch["labels"] = processor(batch["text"]).input_ids
    return batch

# %%
timit = timit.map(prepare_dataset, remove_columns=timit.column_names["train"], num_proc=4)
# Out:
# 2023-12-09 20:44:56.138440: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-09 20:44:56.138437: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-09 20:44:56.138612: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-09 20:44:56.138612: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-09 20:44:56.138720: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-09 20:44:56.138723: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-09 20:44:56.142956: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-09 20:44:56.142952: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-09 20:44:56.143107: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-09 20:44:56.143108: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-09 20:44:56.143280: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-09 20:44:56.143284: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-09 20:44:56.165464: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-09 20:44:56.165462: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-09 20:44:56.172352: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-09 20:44:56.172813: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-09 20:44:59.804250: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-12-09 20:44:59.840983: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-12-09 20:45:00.010596: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-12-09 20:45:00.010593: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /home/kmb85/.local/lib/python3.10/site-packages/datasets/table.py:690: FutureWarning: promote has been superseded by mode='default'.
#   table = cls._concat_blocks(blocks, axis=0)
# 2023-12-09 20:46:44.282692: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-09 20:46:44.283023: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-09 20:46:44.283196: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-09 20:46:44.321914: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-09 20:46:48.829929: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-12-09 20:47:39.039327: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-09 20:47:39.039644: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-09 20:47:39.039795: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-09 20:47:39.041954: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-09 20:47:39.042140: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-09 20:47:39.042320: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-09 20:47:39.071501: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-09 20:47:39.078894: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-09 20:47:39.635879: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-09 20:47:39.636119: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-09 20:47:39.636225: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-09 20:47:39.664224: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-09 20:47:42.889077: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-12-09 20:47:42.917740: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2023-12-09 20:47:43.662549: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
max_input_length_in_sec = 4.0
timit["train"] = timit["train"].filter(lambda x: x < max_input_length_in_sec * processor.feature_extractor.sampling_rate, input_columns=["input_length"])
# Out:
#   0%|          | 0/5 [00:00<?, ?ba/s]

# %% [markdown]
# Now we are ready to start training!

# %% [markdown]
# ### Set-up Trainer
#
# Let's start by defining the data collator. The code for the data collator was copied from [this example](https://github.com/huggingface/transformers/blob/9a06b6b11bdfc42eea08fa91d0c737d1863c99e3/examples/research_projects/wav2vec2/run_asr.py#L81).

# %%
import torch

from dataclasses import dataclass, field
from typing import Any, Dict, List, Optional, Union

@dataclass
class DataCollatorCTCWithPadding:
    """
    Data collator that will dynamically pad the inputs received.
    Args:
        processor (:class:`~transformers.Wav2Vec2Processor`)
            The processor used for proccessing the data.
        padding (:obj:`bool`, :obj:`str` or :class:`~transformers.tokenization_utils_base.PaddingStrategy`, `optional`, defaults to :obj:`True`):
            Select a strategy to pad the returned sequences (according to the model's padding side and padding index)
            among:
            * :obj:`True` or :obj:`'longest'`: Pad to the longest sequence in the batch (or no padding if only a single
              sequence if provided).
            * :obj:`'max_length'`: Pad to a maximum length specified with the argument :obj:`max_length` or to the
              maximum acceptable input length for the model if that argument is not provided.
            * :obj:`False` or :obj:`'do_not_pad'` (default): No padding (i.e., can output a batch with sequences of
              different lengths).
    """

    processor: Wav2Vec2Processor
    padding: Union[bool, str] = True

    def __call__(self, features: List[Dict[str, Union[List[int], torch.Tensor]]]) -> Dict[str, torch.Tensor]:
        # split inputs and labels since they have to be of different lenghts and need
        # different padding methods
        input_features = [{"input_values": feature["input_values"]} for feature in features]
        label_features = [{"input_ids": feature["labels"]} for feature in features]

        batch = self.processor.pad(
            input_features,
            padding=self.padding,
            return_tensors="pt",
        )
        with self.processor.as_target_processor():
            labels_batch = self.processor.pad(
                label_features,
                padding=self.padding,
                return_tensors="pt",
            )

        # replace padding with -100 to ignore loss correctly
        labels = labels_batch["input_ids"].masked_fill(labels_batch.attention_mask.ne(1), -100)

        batch["labels"] = labels

        return batch

# %%
data_collator = DataCollatorCTCWithPadding(processor=processor, padding=True)

# %% [markdown]
# Next, the evaluation metric is defined. As mentioned earlier, the
# predominant metric in ASR is the word error rate (WER), hence we will use it in this notebook as well.

# %%
wer_metric = load_metric("wer")

# %% [markdown]
# The model will return a sequence of logit vectors:
# $\mathbf{y}_1, \ldots, \mathbf{y}_m$ with $\mathbf{y}_1 = f_{\theta}(x_1, \ldots, x_n)[0]$ and $n >> m$.

# %%
def compute_metrics(pred):
    pred_logits = pred.predictions
    pred_ids = np.argmax(pred_logits, axis=-1)

    pred.label_ids[pred.label_ids == -100] = processor.tokenizer.pad_token_id

    pred_str = processor.batch_decode(pred_ids)
    # we do not want to group tokens when computing the metrics
    label_str = processor.batch_decode(pred.label_ids, group_tokens=False)

    wer = wer_metric.compute(predictions=pred_str, references=label_str)

    return {"wer": wer}

# %%
from transformers import Wav2Vec2ForCTC, Trainer
# Out:
# 2023-12-09 20:48:02.416741: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-09 20:48:02.417019: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-09 20:48:02.417207: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-09 20:48:02.457702: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-09 20:48:07.149170: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ## Load Model

# %%
model = Wav2Vec2ForCTC.from_pretrained(
    "facebook/wav2vec2-base",
    ctc_loss_reduction="mean",
    pad_token_id=processor.tokenizer.pad_token_id,
)
model = model.to(device)
# Out:
# /home/kmb85/.local/lib/python3.10/site-packages/transformers/configuration_utils.py:356: UserWarning: Passing `gradient_checkpointing` to a config initialization is deprecated and will be removed in v5 Transformers. Using `model.gradient_checkpointing_enable()` instead, or if you are using the `Trainer` API, pass `gradient_checkpointing=True` in your `TrainingArguments`.
#   warnings.warn(
# /home/kmb85/.local/lib/python3.10/site-packages/torch/nn/utils/weight_norm.py:30: UserWarning: torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.
#   warnings.warn("torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.")
# Some weights of the model checkpoint at facebook/wav2vec2-base were not used when initializing Wav2Vec2ForCTC: ['project_hid.bias', 'project_q.weight', 'project_hid.weight', 'quantizer.weight_proj.bias', 'quantizer.weight_proj.weight', 'project_q.bias', 'quantizer.codevectors']
# - This IS expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of Wav2Vec2ForCTC were not initialized from the model checkpoint at facebook/wav2vec2-base and are newly initialized: ['lm_head.bias', 'lm_head.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
model.eval()

# %%
model.freeze_feature_encoder()

# %% [markdown]
# ## Post-training quantization

# %%
import pytorch_quantization
from pytorch_quantization import nn as quant_nn
from pytorch_quantization import quant_modules
from pytorch_quantization.tensor_quant import QuantDescriptor
from pytorch_quantization import calib

# %%
print(pytorch_quantization.__version__)
# Out:
# 2.1.3

# %%
quant_desc_input = QuantDescriptor(calib_method='max', num_bits=4, fake_quant=True)
quant_nn.QuantConv1d.set_default_quant_desc_input(quant_desc_input)
quant_nn.QuantLinear.set_default_quant_desc_input(quant_desc_input)

# %%
quant_modules.initialize()
model_quantized = Wav2Vec2ForCTC.from_pretrained(
    "facebook/wav2vec2-base",
    ctc_loss_reduction="mean",
    pad_token_id=processor.tokenizer.pad_token_id,
)
# Out:
# /home/kmb85/.local/lib/python3.10/site-packages/transformers/configuration_utils.py:356: UserWarning: Passing `gradient_checkpointing` to a config initialization is deprecated and will be removed in v5 Transformers. Using `model.gradient_checkpointing_enable()` instead, or if you are using the `Trainer` API, pass `gradient_checkpointing=True` in your `TrainingArguments`.
#   warnings.warn(
# /home/kmb85/.local/lib/python3.10/site-packages/torch/nn/utils/weight_norm.py:30: UserWarning: torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.
#   warnings.warn("torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.")
# Some weights of the model checkpoint at facebook/wav2vec2-base were not used when initializing Wav2Vec2ForCTC: ['project_q.weight', 'project_q.bias', 'quantizer.weight_proj.weight', 'project_hid.bias', 'quantizer.weight_proj.bias', 'quantizer.codevectors', 'project_hid.weight']
# - This IS expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of Wav2Vec2ForCTC were not initialized from the model checkpoint at facebook/wav2vec2-base and are newly initialized: ['lm_head.bias', 'lm_head.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
model_quantized = model_quantized.to(device)

# %%
model_quantized.freeze_feature_encoder()

# %% [markdown]
# First, calibrate the quantized model

# %%
for name, module in model_quantized.named_modules():
    if name.endswith('_quantizer'):
        module.enable_calib()
        module.disable_quant()

# %%
with torch.no_grad():
    for i in range(2000):
            _ = model_quantized(torch.tensor(timit["train"][i:i+1]["input_values"], device="cuda"))

# %%
# Finalize calibration
for name, module in model_quantized.named_modules():
    if name.endswith('_quantizer'):
        module.load_calib_amax()
        module.disable_calib()
        module.enable_quant()

# If running on GPU, it needs to call .cuda() again because new tensors will be created by calibration process
model_quantized.cuda()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W1209 20:12:40.193376 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# W1209 20:12:40.199936 140561437851648 tensor_quantizer.py:239] Call .cuda() if running on GPU after loading calibrated amax.
# W1209 20:12:40.201923 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.203469 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([512, 1, 1]).
# W1209 20:12:40.204797 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.206634 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# W1209 20:12:40.208471 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.210765 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([512, 1, 1]).
# W1209 20:12:40.212064 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.213403 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# W1209 20:12:40.214677 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.215964 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([512, 1, 1]).
# W1209 20:12:40.217184 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.218673 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# W1209 20:12:40.220087 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.221587 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([512, 1, 1]).
# W1209 20:12:40.224212 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.225696 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# W1209 20:12:40.227152 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.228562 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([512, 1, 1]).
# W1209 20:12:40.229893 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.231468 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# W1209 20:12:40.232745 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.234137 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([512, 1, 1]).
# W1209 20:12:40.235482 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.237079 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# W1209 20:12:40.238587 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.239887 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([512, 1, 1]).
# W1209 20:12:40.241132 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.242618 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# W1209 20:12:40.243949 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.245607 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([768, 1]).
# W1209 20:12:40.246887 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.248142 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# W1209 20:12:40.249314 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.250485 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([768, 1, 1]).
# W1209 20:12:40.251957 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.253219 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# W1209 20:12:40.254461 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.255928 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([768, 1]).
# W1209 20:12:40.257287 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.258711 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# W1209 20:12:40.259996 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.261371 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([768, 1]).
# W1209 20:12:40.262649 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.264029 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# W1209 20:12:40.265194 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.266427 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([768, 1]).
# W1209 20:12:40.267717 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.269865 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# W1209 20:12:40.271108 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.272335 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([768, 1]).
# W1209 20:12:40.274179 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.275440 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# W1209 20:12:40.276725 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.277863 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([3072, 1]).
# W1209 20:12:40.279258 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.283041 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# W1209 20:12:40.284425 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.286615 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([768, 1]).
# W1209 20:12:40.288752 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.290027 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# W1209 20:12:40.291634 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.293657 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([768, 1]).
# W1209 20:12:40.295130 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.296442 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# W1209 20:12:40.297813 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.299557 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([768, 1]).
# W1209 20:12:40.300931 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.302463 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# W1209 20:12:40.304082 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.306514 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([768, 1]).
# W1209 20:12:40.308310 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.309683 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# W1209 20:12:40.311383 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.312667 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([768, 1]).
# W1209 20:12:40.313989 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.315356 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# W1209 20:12:40.318383 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.319860 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([3072, 1]).
# W1209 20:12:40.321449 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.322717 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# W1209 20:12:40.325240 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.326793 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([768, 1]).
# W1209 20:12:40.328462 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.330142 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# W1209 20:12:40.331707 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.333087 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([768, 1]).
# W1209 20:12:40.334739 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.336021 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# W1209 20:12:40.337777 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.339468 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([768, 1]).
# W1209 20:12:40.340790 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.342412 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# W1209 20:12:40.343696 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.345030 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([768, 1]).
# W1209 20:12:40.346366 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.347586 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# W1209 20:12:40.349061 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.350534 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([768, 1]).
# W1209 20:12:40.352063 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.353758 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# W1209 20:12:40.355052 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.356220 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([3072, 1]).
# W1209 20:12:40.359133 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.360440 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# W1209 20:12:40.361931 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.363673 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([768, 1]).
# W1209 20:12:40.364946 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.366173 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# W1209 20:12:40.367874 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.369102 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([768, 1]).
# W1209 20:12:40.370660 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.372017 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# W1209 20:12:40.373564 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.374803 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([768, 1]).
# W1209 20:12:40.376818 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.378211 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# W1209 20:12:40.380213 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.382800 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([768, 1]).
# W1209 20:12:40.384195 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.385718 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# W1209 20:12:40.386864 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.388217 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([768, 1]).
# W1209 20:12:40.390023 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.391707 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# W1209 20:12:40.393738 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.395121 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([3072, 1]).
# W1209 20:12:40.396385 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.398054 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# W1209 20:12:40.399651 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.401096 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([768, 1]).
# W1209 20:12:40.402480 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.403935 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# W1209 20:12:40.407519 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.410051 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([768, 1]).
# W1209 20:12:40.411573 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.413228 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# W1209 20:12:40.414828 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.416259 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([768, 1]).
# W1209 20:12:40.418594 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.420171 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# W1209 20:12:40.422590 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.423951 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([768, 1]).
# W1209 20:12:40.425291 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.426531 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# W1209 20:12:40.428434 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.429635 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([768, 1]).
# W1209 20:12:40.430880 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.432293 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# W1209 20:12:40.433637 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.434886 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([3072, 1]).
# W1209 20:12:40.436253 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.437642 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# W1209 20:12:40.438845 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.440230 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([768, 1]).
# W1209 20:12:40.441677 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.443646 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# W1209 20:12:40.444998 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.446184 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([768, 1]).
# W1209 20:12:40.447551 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.448768 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# W1209 20:12:40.450181 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.451568 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([768, 1]).
# W1209 20:12:40.452798 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.454189 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# W1209 20:12:40.455900 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.457139 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([768, 1]).
# W1209 20:12:40.458723 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.460044 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# W1209 20:12:40.461554 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.462817 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([768, 1]).
# W1209 20:12:40.464169 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.465495 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# W1209 20:12:40.466809 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.468062 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([3072, 1]).
# W1209 20:12:40.469334 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.470601 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# W1209 20:12:40.472901 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.474139 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([768, 1]).
# W1209 20:12:40.475651 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.476825 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# W1209 20:12:40.478802 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.480103 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([768, 1]).
# W1209 20:12:40.481380 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.482482 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# W1209 20:12:40.483789 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.485002 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([768, 1]).
# W1209 20:12:40.486534 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.487605 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# W1209 20:12:40.489241 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.490882 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([768, 1]).
# W1209 20:12:40.492254 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.493512 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# W1209 20:12:40.495038 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.496369 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([768, 1]).
# W1209 20:12:40.498813 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.501701 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# W1209 20:12:40.503010 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.504221 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([3072, 1]).
# W1209 20:12:40.505538 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.506972 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# W1209 20:12:40.508265 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.509633 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([768, 1]).
# W1209 20:12:40.511734 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.513100 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# W1209 20:12:40.514493 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.515733 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([768, 1]).
# W1209 20:12:40.516916 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.518218 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# W1209 20:12:40.519521 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.520804 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([768, 1]).
# W1209 20:12:40.522151 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.523432 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# W1209 20:12:40.524847 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.526064 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([768, 1]).
# W1209 20:12:40.527409 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.528758 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# W1209 20:12:40.530085 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.531364 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([768, 1]).
# W1209 20:12:40.532670 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.534297 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# W1209 20:12:40.535834 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.537135 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([3072, 1]).
# W1209 20:12:40.538465 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.539898 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# W1209 20:12:40.541106 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.542378 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([768, 1]).
# W1209 20:12:40.543576 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.545062 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# W1209 20:12:40.546314 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.548224 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([768, 1]).
# W1209 20:12:40.549334 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.550661 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# W1209 20:12:40.551886 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.553112 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([768, 1]).
# W1209 20:12:40.554461 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.555891 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# W1209 20:12:40.557225 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.558372 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([768, 1]).
# W1209 20:12:40.560026 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.561579 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# W1209 20:12:40.562756 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.564534 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([768, 1]).
# W1209 20:12:40.566176 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.567605 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# W1209 20:12:40.568921 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.570115 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([3072, 1]).
# W1209 20:12:40.571391 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.574792 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# W1209 20:12:40.576045 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.577480 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([768, 1]).
# W1209 20:12:40.578727 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.579955 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# W1209 20:12:40.581210 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.582488 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([768, 1]).
# W1209 20:12:40.583858 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.585316 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# W1209 20:12:40.586646 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.587859 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([768, 1]).
# W1209 20:12:40.589092 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.590415 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# W1209 20:12:40.591683 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.592980 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([768, 1]).
# W1209 20:12:40.595179 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.596452 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# W1209 20:12:40.597811 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.599441 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([768, 1]).
# W1209 20:12:40.600660 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.602069 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# W1209 20:12:40.603418 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.604583 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([3072, 1]).
# W1209 20:12:40.605895 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.607090 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# W1209 20:12:40.608352 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.609511 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([768, 1]).
# W1209 20:12:40.610860 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.612538 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# W1209 20:12:40.613763 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.615097 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([768, 1]).
# W1209 20:12:40.616372 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.617528 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# W1209 20:12:40.618849 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.621774 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([768, 1]).
# W1209 20:12:40.623121 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.624663 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# W1209 20:12:40.628344 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.630189 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([768, 1]).
# W1209 20:12:40.631686 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.633089 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# W1209 20:12:40.634595 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.635935 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([768, 1]).
# W1209 20:12:40.637355 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.638700 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# W1209 20:12:40.639928 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.641189 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([3072, 1]).
# W1209 20:12:40.642448 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.643922 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# W1209 20:12:40.645136 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.646424 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([768, 1]).
# W1209 20:12:40.647743 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.649134 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# W1209 20:12:40.650377 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.651647 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([768, 1]).
# W1209 20:12:40.652882 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.654128 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# W1209 20:12:40.655462 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.656755 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([768, 1]).
# W1209 20:12:40.658088 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.659431 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# W1209 20:12:40.660701 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.661982 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([768, 1]).
# W1209 20:12:40.663362 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.664793 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# W1209 20:12:40.665937 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.667218 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([768, 1]).
# W1209 20:12:40.668526 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.669736 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# W1209 20:12:40.670993 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.672204 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([3072, 1]).
# W1209 20:12:40.673418 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.674649 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# W1209 20:12:40.676046 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.677276 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([768, 1]).
# W1209 20:12:40.678475 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.679789 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([]).
# W1209 20:12:40.681024 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# W1209 20:12:40.682196 140561437851648 tensor_quantizer.py:238] Load calibrated amax, shape=torch.Size([32, 1]).
# W1209 20:12:40.683594 140561437851648 tensor_quantizer.py:174] Disable MaxCalibrator
# Wav2Vec2ForCTC(
#   (wav2vec2): Wav2Vec2Model(
#     (feature_extractor): Wav2Vec2FeatureEncoder(
#       (conv_layers): ModuleList(
#         (0): Wav2Vec2GroupNormConvLayer(
#           (conv): QuantConv1d(
#             1, 512, kernel_size=(10,), stride=(5,), bias=False
#             (_input_quantizer): TensorQuantizer(4bit fake per-tensor amax=22.2899 calibrator=MaxCalibrator scale=1.0 quant)
#             (_weight_quantizer): TensorQuantizer(8bit fake axis=0 amax=[0.0119, 0.6792](512) calibrator=MaxCalibrator scale=1.0 quant)
#           )
#           (activation): GELUActivation()
#           (layer_norm): GroupNorm(512, 512, eps=1e-05, affine=True)
#         )
#         (1): Wav2Vec2NoLayerNormConvLayer(
#           (conv): QuantConv1d(
#             512, 512, kernel_size=(3,), stride=(2,), bias=False
#             (_input_quantizer): TensorQuantizer(4bit fake per-tensor amax=131.2755 calibrator=MaxCalibrator scale=1.0 quant)
#             (_weight_quantizer): TensorQuantizer(8bit fake axis=0 amax=[0.1276, 3.5957](512) calibrator=MaxCalibrator scale=1.0 quant)
#           )
#           (activation): GELUActivation()
#         )
#         (2): Wav2Vec2NoLayerNormConvLayer(
#           (conv): QuantConv1d(
#             512, 512, kernel_size=(3,), stride=(2,), bias=False
#             (_input_quantizer): TensorQuantizer(4bit fake per-tensor amax=559.4791 calibrator=MaxCalibrator scale=1.0 quant)
#             (_weight_quantizer): TensorQuantizer(8bit fake axis=0 amax=[0.1477, 3.9121](512) calibrator=MaxCalibrator scale=1.0 quant)
#           )
#           (activation): GELUActivation()
#         )
#         (3): Wav2Vec2NoLayerNormConvLayer(
#           (conv): QuantConv1d(
#             512, 512, kernel_size=(3,), stride=(2,), bias=False
#             (_input_quantizer): TensorQuantizer(4bit fake per-tensor amax=36.3066 calibrator=MaxCalibrator scale=1.0 quant)
#             (_weight_quantizer): TensorQuantizer(8bit fake axis=0 amax=[0.1323, 3.5469](512) calibrator=MaxCalibrator scale=1.0 quant)
#           )
#           (activation): GELUActivation()
#         )
#         (4): Wav2Vec2NoLayerNormConvLayer(
#           (conv): QuantConv1d(
#             512, 512, kernel_size=(3,), stride=(2,), bias=False
#             (_input_quantizer): TensorQuantizer(4bit fake per-tensor amax=17.1718 calibrator=MaxCalibrator scale=1.0 quant)
#             (_weight_quantizer): TensorQuantizer(8bit fake axis=0 amax=[0.1304, 2.0234](512) calibrator=MaxCalibrator scale=1.0 quant)
#           )
#           (activation): GELUActivation()
#         )
#         (5): Wav2Vec2NoLayerNormConvLayer(
#           (conv): QuantConv1d(
#             512, 512, kernel_size=(2,), stride=(2,), bias=False
#             (_input_quantizer): TensorQuantizer(4bit fake per-tensor amax=7.1219 calibrator=MaxCalibrator scale=1.0 quant)
#             (_weight_quantizer): TensorQuantizer(8bit fake axis=0 amax=[0.0952, 1.0703](512) calibrator=MaxCalibrator scale=1.0 quant)
#           )
#           (activation): GELUActivation()
#         )
#         (6): Wav2Vec2NoLayerNormConvLayer(
#           (conv): QuantConv1d(
#             512, 512, kernel_size=(2,), stride=(2,), bias=False
#             (_input_quantizer): TensorQuantizer(4bit fake per-tensor amax=8.2503 calibrator=MaxCalibrator scale=1.0 quant)
#             (_weight_quantizer): TensorQuantizer(8bit fake axis=0 amax=[0.0579, 0.3494](512) calibrator=MaxCalibrator scale=1.0 quant)
#           )
#           (activation): GELUActivation()
#         )
#       )
#     )
#     (feature_projection): Wav2Vec2FeatureProjection(
#       (layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       (projection): QuantLinear(
#         in_features=512, out_features=768, bias=True
#         (_input_quantizer): TensorQuantizer(4bit fake per-tensor amax=3.0796 calibrator=MaxCalibrator scale=1.0 quant)
#         (_weight_quantizer): TensorQuantizer(8bit fake axis=0 amax=[0.1080, 0.9385](768) calibrator=MaxCalibrator scale=1.0 quant)
#       )
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): Wav2Vec2Encoder(
#       (pos_conv_embed): Wav2Vec2PositionalConvEmbedding(
#         (conv): QuantConv1d(
#           768, 768, kernel_size=(128,), stride=(1,), padding=(64,), groups=16
#           (_input_quantizer): TensorQuantizer(4bit fake per-tensor amax=10.3169 calibrator=MaxCalibrator scale=1.0 quant)
#           (_weight_quantizer): TensorQuantizer(8bit fake axis=0 amax=[0.0410, 1.0699](768) calibrator=MaxCalibrator scale=1.0 quant)
#         )
#         (padding): Wav2Vec2SamePadLayer()
#         (activation): GELUActivation()
#       )
#       (layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#       (layers): ModuleList(
#         (0): Wav2Vec2EncoderLayer(
#           (attention): Wav2Vec2Attention(
#             (k_proj): QuantLinear(
#               in_features=768, out_features=768, bias=True
#               (_input_quantizer): TensorQuantizer(4bit fake per-tensor amax=3.3054 calibrator=MaxCalibrator scale=1.0 quant)
#               (_weight_quantizer): TensorQuantizer(8bit fake axis=0 amax=[0.1655, 1.2773](768) calibrator=MaxCalibrator scale=1.0 quant)
#             )
#             (v_proj): QuantLinear(
#               in_features=768, out_features=768, bias=True
#               (_input_quantizer): TensorQuantizer(4bit fake per-tensor amax=3.3054 calibrator=MaxCalibrator scale=1.0 quant)
#               (_weight_quantizer): TensorQuantizer(8bit fake axis=0 amax=[0.0836, 0.9814](768) calibrator=MaxCalibrator scale=1.0 quant)
#             )
#             (q_proj): QuantLinear(
#               in_features=768, out_features=768, bias=True
#               (_input_quantizer): TensorQuantizer(4bit fake per-tensor amax=3.3054 calibrator=MaxCalibrator scale=1.0 quant)
#               (_weight_quantizer): TensorQuantizer(8bit fake axis=0 amax=[0.1846, 0.9370](768) calibrator=MaxCalibrator scale=1.0 quant)
#             )
#             (out_proj): QuantLinear(
#               in_features=768, out_features=768, bias=True
#               (_input_quantizer): TensorQuantizer(4bit fake per-tensor amax=1.6044 calibrator=MaxCalibrator scale=1.0 quant)
#               (_weight_quantizer): TensorQuantizer(8bit fake axis=0 amax=[0.0633, 0.8091](768) calibrator=MaxCalibrator scale=1.0 quant)
#             )
#           )
#           (dropout): Dropout(p=0.1, inplace=False)
#           (layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (feed_forward): Wav2Vec2FeedForward(
#             (intermediate_dropout): Dropout(p=0.0, inplace=False)
#             (intermediate_dense): QuantLinear(
#               in_features=768, out_features=3072, bias=True
#               (_input_quantizer): TensorQuantizer(4bit fake per-tensor amax=7.8231 calibrator=MaxCalibrator scale=1.0 quant)
#               (_weight_quantizer): TensorQuantizer(8bit fake axis=0 amax=[0.1682, 1.7686](3072) calibrator=MaxCalibrator scale=1.0 quant)
#             )
#             (intermediate_act_fn): GELUActivation()
#             (output_dense): QuantLinear(
#               in_features=3072, out_features=768, bias=True
#               (_input_quantizer): TensorQuantizer(4bit fake per-tensor amax=6.8866 calibrator=MaxCalibrator scale=1.0 quant)
#               (_weight_quantizer): TensorQuantizer(8bit fake axis=0 amax=[0.2268, 1.2012](768) calibrator=MaxCalibrator scale=1.0 quant)
#             )
#             (output_dropout): Dropout(p=0.1, inplace=False)
#           )
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (1): Wav2Vec2EncoderLayer(
#           (attention): Wav2Vec2Attention(
#             (k_proj): QuantLinear(
#               in_features=768, out_features=768, bias=True
#               (_input_quantizer): TensorQuantizer(4bit fake per-tensor amax=3.9125 calibrator=MaxCalibrator scale=1.0 quant)
#               (_weight_quantizer): TensorQuantizer(8bit fake axis=0 amax=[0.2224, 1.3838](768) calibrator=MaxCalibrator scale=1.0 quant)
#             )
#             (v_proj): QuantLinear(
#               in_features=768, out_features=768, bias=True
#               (_input_quantizer): TensorQuantizer(4bit fake per-tensor amax=3.9125 calibrator=MaxCalibrator scale=1.0 quant)
#               (_weight_quantizer): TensorQuantizer(8bit fake axis=0 amax=[0.0694, 0.4868](768) calibrator=MaxCalibrator scale=1.0 quant)
#             )
#             (q_proj): QuantLinear(
#               in_features=768, out_features=768, bias=True
#               (_input_quantizer): TensorQuantizer(4bit fake per-tensor amax=3.9125 calibrator=MaxCalibrator scale=1.0 quant)
#               (_weight_quantizer): TensorQuantizer(8bit fake axis=0 amax=[0.2144, 1.2627](768) calibrator=MaxCalibrator scale=1.0 quant)
#             )
#             (out_proj): QuantLinear(
#               in_features=768, out_features=768, bias=True
#               (_input_quantizer): TensorQuantizer(4bit fake per-tensor amax=1.4654 calibrator=MaxCalibrator scale=1.0 quant)
#               (_weight_quantizer): TensorQuantizer(8bit fake axis=0 amax=[0.0863, 0.6289](768) calibrator=MaxCalibrator scale=1.0 quant)
#             )
#           )
#           (dropout): Dropout(p=0.1, inplace=False)
#           (layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (feed_forward): Wav2Vec2FeedForward(
#             (intermediate_dropout): Dropout(p=0.0, inplace=False)
#             (intermediate_dense): QuantLinear(
#               in_features=768, out_features=3072, bias=True
#               (_input_quantizer): TensorQuantizer(4bit fake per-tensor amax=9.9850 calibrator=MaxCalibrator scale=1.0 quant)
#               (_weight_quantizer): TensorQuantizer(8bit fake axis=0 amax=[0.1818, 1.5820](3072) calibrator=MaxCalibrator scale=1.0 quant)
#             )
#             (intermediate_act_fn): GELUActivation()
#             (output_dense): QuantLinear(
#               in_features=3072, out_features=768, bias=True
#               (_input_quantizer): TensorQuantizer(4bit fake per-tensor amax=6.4166 calibrator=MaxCalibrator scale=1.0 quant)
#               (_weight_quantizer): TensorQuantizer(8bit fake axis=0 amax=[0.2418, 1.4932](768) calibrator=MaxCalibrator scale=1.0 quant)
#             )
#             (output_dropout): Dropout(p=0.1, inplace=False)
#           )
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (2): Wav2Vec2EncoderLayer(
#           (attention): Wav2Vec2Attention(
#             (k_proj): QuantLinear(
#               in_features=768, out_features=768, bias=True
#               (_input_quantizer): TensorQuantizer(4bit fake per-tensor amax=4.4937 calibrator=MaxCalibrator scale=1.0 quant)
#               (_weight_quantizer): TensorQuantizer(8bit fake axis=0 amax=[0.2134, 0.8926](768) calibrator=MaxCalibrator scale=1.0 quant)
#             )
#             (v_proj): QuantLinear(
#               in_features=768, out_features=768, bias=True
#               (_input_quantizer): TensorQuantizer(4bit fake per-tensor amax=4.4937 calibrator=MaxCalibrator scale=1.0 quant)
#               (_weight_quantizer): TensorQuantizer(8bit fake axis=0 amax=[0.1110, 0.3303](768) calibrator=MaxCalibrator scale=1.0 quant)
#             )
#             (q_proj): QuantLinear(
#               in_features=768, out_features=768, bias=True
#               (_input_quantizer): TensorQuantizer(4bit fake per-tensor amax=4.4937 calibrator=MaxCalibrator scale=1.0 quant)
#               (_weight_quantizer): TensorQuantizer(8bit fake axis=0 amax=[0.2144, 1.0146](768) calibrator=MaxCalibrator scale=1.0 quant)
#             )
#             (out_proj): QuantLinear(
#               in_features=768, out_features=768, bias=True
#               (_input_quantizer): TensorQuantizer(4bit fake per-tensor amax=1.7649 calibrator=MaxCalibrator scale=1.0 quant)
#               (_weight_quantizer): TensorQuantizer(8bit fake axis=0 amax=[0.0578, 0.4016](768) calibrator=MaxCalibrator scale=1.0 quant)
#             )
#           )
#           (dropout): Dropout(p=0.1, inplace=False)
#           (layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (feed_forward): Wav2Vec2FeedForward(
#             (intermediate_dropout): Dropout(p=0.0, inplace=False)
#             (intermediate_dense): QuantLinear(
#               in_features=768, out_features=3072, bias=True
#               (_input_quantizer): TensorQuantizer(4bit fake per-tensor amax=17.7049 calibrator=MaxCalibrator scale=1.0 quant)
#               (_weight_quantizer): TensorQuantizer(8bit fake axis=0 amax=[0.1705, 1.4775](3072) calibrator=MaxCalibrator scale=1.0 quant)
#             )
#             (intermediate_act_fn): GELUActivation()
#             (output_dense): QuantLinear(
#               in_features=3072, out_features=768, bias=True
#               (_input_quantizer): TensorQuantizer(4bit fake per-tensor amax=9.1496 calibrator=MaxCalibrator scale=1.0 quant)
#               (_weight_quantizer): TensorQuantizer(8bit fake axis=0 amax=[0.2325, 1.0645](768) calibrator=MaxCalibrator scale=1.0 quant)
#             )
#             (output_dropout): Dropout(p=0.1, inplace=False)
#           )
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (3): Wav2Vec2EncoderLayer(
#           (attention): Wav2Vec2Attention(
#             (k_proj): QuantLinear(
#               in_features=768, out_features=768, bias=True
#               (_input_quantizer): TensorQuantizer(4bit fake per-tensor amax=4.7300 calibrator=MaxCalibrator scale=1.0 quant)
#               (_weight_quantizer): TensorQuantizer(8bit fake axis=0 amax=[0.2196, 1.0625](768) calibrator=MaxCalibrator scale=1.0 quant)
#             )
#             (v_proj): QuantLinear(
#               in_features=768, out_features=768, bias=True
#               (_input_quantizer): TensorQuantizer(4bit fake per-tensor amax=4.7300 calibrator=MaxCalibrator scale=1.0 quant)
#               (_weight_quantizer): TensorQuantizer(8bit fake axis=0 amax=[0.1219, 0.3979](768) calibrator=MaxCalibrator scale=1.0 quant)
#             )
#             (q_proj): QuantLinear(
#               in_features=768, out_features=768, bias=True
#               (_input_quantizer): TensorQuantizer(4bit fake per-tensor amax=4.7300 calibrator=MaxCalibrator scale=1.0 quant)
#               (_weight_quantizer): TensorQuantizer(8bit fake axis=0 amax=[0.2201, 0.7861](768) calibrator=MaxCalibrator scale=1.0 quant)
#             )
#             (out_proj): QuantLinear(
#               in_features=768, out_features=768, bias=True
#               (_input_quantizer): TensorQuantizer(4bit fake per-tensor amax=1.8229 calibrator=MaxCalibrator scale=1.0 quant)
#               (_weight_quantizer): TensorQuantizer(8bit fake axis=0 amax=[0.0448, 0.4414](768) calibrator=MaxCalibrator scale=1.0 quant)
#             )
#           )
#           (dropout): Dropout(p=0.1, inplace=False)
#           (layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (feed_forward): Wav2Vec2FeedForward(
#             (intermediate_dropout): Dropout(p=0.0, inplace=False)
#             (intermediate_dense): QuantLinear(
#               in_features=768, out_features=3072, bias=True
#               (_input_quantizer): TensorQuantizer(4bit fake per-tensor amax=20.1100 calibrator=MaxCalibrator scale=1.0 quant)
#               (_weight_quantizer): TensorQuantizer(8bit fake axis=0 amax=[0.1411, 0.7422](3072) calibrator=MaxCalibrator scale=1.0 quant)
#             )
#             (intermediate_act_fn): GELUActivation()
#             (output_dense): QuantLinear(
#               in_features=3072, out_features=768, bias=True
#               (_input_quantizer): TensorQuantizer(4bit fake per-tensor amax=23.3963 calibrator=MaxCalibrator scale=1.0 quant)
#               (_weight_quantizer): TensorQuantizer(8bit fake axis=0 amax=[0.1664, 1.9316](768) calibrator=MaxCalibrator scale=1.0 quant)
#             )
#             (output_dropout): Dropout(p=0.1, inplace=False)
#           )
# ...
#             )
#             (out_proj): QuantLinear(
#               in_features=768, out_features=768, bias=True
#               (_input_quantizer): TensorQuantizer(4bit fake per-tensor amax=1.9715 calibrator=MaxCalibrator scale=1.0 quant)
#               (_weight_quantizer): TensorQuantizer(8bit fake axis=0 amax=[0.0184, 0.8145](768) calibrator=MaxCalibrator scale=1.0 quant)
#             )
#           )
#           (dropout): Dropout(p=0.1, inplace=False)
#           (layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (feed_forward): Wav2Vec2FeedForward(
#             (intermediate_dropout): Dropout(p=0.0, inplace=False)
#             (intermediate_dense): QuantLinear(
#               in_features=768, out_features=3072, bias=True
#               (_input_quantizer): TensorQuantizer(4bit fake per-tensor amax=60.5501 calibrator=MaxCalibrator scale=1.0 quant)
#               (_weight_quantizer): TensorQuantizer(8bit fake axis=0 amax=[0.1091, 0.7812](3072) calibrator=MaxCalibrator scale=1.0 quant)
#             )
#             (intermediate_act_fn): GELUActivation()
#             (output_dense): QuantLinear(
#               in_features=3072, out_features=768, bias=True
#               (_input_quantizer): TensorQuantizer(4bit fake per-tensor amax=9.8029 calibrator=MaxCalibrator scale=1.0 quant)
#               (_weight_quantizer): TensorQuantizer(8bit fake axis=0 amax=[0.0527, 1.4697](768) calibrator=MaxCalibrator scale=1.0 quant)
#             )
#             (output_dropout): Dropout(p=0.1, inplace=False)
#           )
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (7): Wav2Vec2EncoderLayer(
#           (attention): Wav2Vec2Attention(
#             (k_proj): QuantLinear(
#               in_features=768, out_features=768, bias=True
#               (_input_quantizer): TensorQuantizer(4bit fake per-tensor amax=4.6455 calibrator=MaxCalibrator scale=1.0 quant)
#               (_weight_quantizer): TensorQuantizer(8bit fake axis=0 amax=[0.2522, 1.0449](768) calibrator=MaxCalibrator scale=1.0 quant)
#             )
#             (v_proj): QuantLinear(
#               in_features=768, out_features=768, bias=True
#               (_input_quantizer): TensorQuantizer(4bit fake per-tensor amax=4.6455 calibrator=MaxCalibrator scale=1.0 quant)
#               (_weight_quantizer): TensorQuantizer(8bit fake axis=0 amax=[0.1377, 0.4265](768) calibrator=MaxCalibrator scale=1.0 quant)
#             )
#             (q_proj): QuantLinear(
#               in_features=768, out_features=768, bias=True
#               (_input_quantizer): TensorQuantizer(4bit fake per-tensor amax=4.6455 calibrator=MaxCalibrator scale=1.0 quant)
#               (_weight_quantizer): TensorQuantizer(8bit fake axis=0 amax=[0.2551, 0.7773](768) calibrator=MaxCalibrator scale=1.0 quant)
#             )
#             (out_proj): QuantLinear(
#               in_features=768, out_features=768, bias=True
#               (_input_quantizer): TensorQuantizer(4bit fake per-tensor amax=3.0480 calibrator=MaxCalibrator scale=1.0 quant)
#               (_weight_quantizer): TensorQuantizer(8bit fake axis=0 amax=[0.0141, 1.0410](768) calibrator=MaxCalibrator scale=1.0 quant)
#             )
#           )
#           (dropout): Dropout(p=0.1, inplace=False)
#           (layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (feed_forward): Wav2Vec2FeedForward(
#             (intermediate_dropout): Dropout(p=0.0, inplace=False)
#             (intermediate_dense): QuantLinear(
#               in_features=768, out_features=3072, bias=True
#               (_input_quantizer): TensorQuantizer(4bit fake per-tensor amax=43.2135 calibrator=MaxCalibrator scale=1.0 quant)
#               (_weight_quantizer): TensorQuantizer(8bit fake axis=0 amax=[0.1161, 0.8628](3072) calibrator=MaxCalibrator scale=1.0 quant)
#             )
#             (intermediate_act_fn): GELUActivation()
#             (output_dense): QuantLinear(
#               in_features=3072, out_features=768, bias=True
#               (_input_quantizer): TensorQuantizer(4bit fake per-tensor amax=43.1748 calibrator=MaxCalibrator scale=1.0 quant)
#               (_weight_quantizer): TensorQuantizer(8bit fake axis=0 amax=[0.0490, 4.5000](768) calibrator=MaxCalibrator scale=1.0 quant)
#             )
#             (output_dropout): Dropout(p=0.1, inplace=False)
#           )
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (8): Wav2Vec2EncoderLayer(
#           (attention): Wav2Vec2Attention(
#             (k_proj): QuantLinear(
#               in_features=768, out_features=768, bias=True
#               (_input_quantizer): TensorQuantizer(4bit fake per-tensor amax=5.0452 calibrator=MaxCalibrator scale=1.0 quant)
#               (_weight_quantizer): TensorQuantizer(8bit fake axis=0 amax=[0.2377, 1.1416](768) calibrator=MaxCalibrator scale=1.0 quant)
#             )
#             (v_proj): QuantLinear(
#               in_features=768, out_features=768, bias=True
#               (_input_quantizer): TensorQuantizer(4bit fake per-tensor amax=5.0452 calibrator=MaxCalibrator scale=1.0 quant)
#               (_weight_quantizer): TensorQuantizer(8bit fake axis=0 amax=[0.1558, 0.4373](768) calibrator=MaxCalibrator scale=1.0 quant)
#             )
#             (q_proj): QuantLinear(
#               in_features=768, out_features=768, bias=True
#               (_input_quantizer): TensorQuantizer(4bit fake per-tensor amax=5.0452 calibrator=MaxCalibrator scale=1.0 quant)
#               (_weight_quantizer): TensorQuantizer(8bit fake axis=0 amax=[0.2406, 0.7993](768) calibrator=MaxCalibrator scale=1.0 quant)
#             )
#             (out_proj): QuantLinear(
#               in_features=768, out_features=768, bias=True
#               (_input_quantizer): TensorQuantizer(4bit fake per-tensor amax=2.3446 calibrator=MaxCalibrator scale=1.0 quant)
#               (_weight_quantizer): TensorQuantizer(8bit fake axis=0 amax=[0.0196, 0.8638](768) calibrator=MaxCalibrator scale=1.0 quant)
#             )
#           )
#           (dropout): Dropout(p=0.1, inplace=False)
#           (layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (feed_forward): Wav2Vec2FeedForward(
#             (intermediate_dropout): Dropout(p=0.0, inplace=False)
#             (intermediate_dense): QuantLinear(
#               in_features=768, out_features=3072, bias=True
#               (_input_quantizer): TensorQuantizer(4bit fake per-tensor amax=18.3211 calibrator=MaxCalibrator scale=1.0 quant)
#               (_weight_quantizer): TensorQuantizer(8bit fake axis=0 amax=[0.1300, 0.8286](3072) calibrator=MaxCalibrator scale=1.0 quant)
#             )
#             (intermediate_act_fn): GELUActivation()
#             (output_dense): QuantLinear(
#               in_features=3072, out_features=768, bias=True
#               (_input_quantizer): TensorQuantizer(4bit fake per-tensor amax=25.3431 calibrator=MaxCalibrator scale=1.0 quant)
#               (_weight_quantizer): TensorQuantizer(8bit fake axis=0 amax=[0.0776, 3.0332](768) calibrator=MaxCalibrator scale=1.0 quant)
#             )
#             (output_dropout): Dropout(p=0.1, inplace=False)
#           )
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (9): Wav2Vec2EncoderLayer(
#           (attention): Wav2Vec2Attention(
#             (k_proj): QuantLinear(
#               in_features=768, out_features=768, bias=True
#               (_input_quantizer): TensorQuantizer(4bit fake per-tensor amax=5.1414 calibrator=MaxCalibrator scale=1.0 quant)
#               (_weight_quantizer): TensorQuantizer(8bit fake axis=0 amax=[0.2013, 1.0693](768) calibrator=MaxCalibrator scale=1.0 quant)
#             )
#             (v_proj): QuantLinear(
#               in_features=768, out_features=768, bias=True
#               (_input_quantizer): TensorQuantizer(4bit fake per-tensor amax=5.1414 calibrator=MaxCalibrator scale=1.0 quant)
#               (_weight_quantizer): TensorQuantizer(8bit fake axis=0 amax=[0.1438, 0.3154](768) calibrator=MaxCalibrator scale=1.0 quant)
#             )
#             (q_proj): QuantLinear(
#               in_features=768, out_features=768, bias=True
#               (_input_quantizer): TensorQuantizer(4bit fake per-tensor amax=5.1414 calibrator=MaxCalibrator scale=1.0 quant)
#               (_weight_quantizer): TensorQuantizer(8bit fake axis=0 amax=[0.2169, 0.8438](768) calibrator=MaxCalibrator scale=1.0 quant)
#             )
#             (out_proj): QuantLinear(
#               in_features=768, out_features=768, bias=True
#               (_input_quantizer): TensorQuantizer(4bit fake per-tensor amax=1.8734 calibrator=MaxCalibrator scale=1.0 quant)
#               (_weight_quantizer): TensorQuantizer(8bit fake axis=0 amax=[0.0508, 0.4280](768) calibrator=MaxCalibrator scale=1.0 quant)
#             )
#           )
#           (dropout): Dropout(p=0.1, inplace=False)
#           (layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (feed_forward): Wav2Vec2FeedForward(
#             (intermediate_dropout): Dropout(p=0.0, inplace=False)
#             (intermediate_dense): QuantLinear(
#               in_features=768, out_features=3072, bias=True
#               (_input_quantizer): TensorQuantizer(4bit fake per-tensor amax=12.5302 calibrator=MaxCalibrator scale=1.0 quant)
#               (_weight_quantizer): TensorQuantizer(8bit fake axis=0 amax=[0.1088, 1.3896](3072) calibrator=MaxCalibrator scale=1.0 quant)
#             )
#             (intermediate_act_fn): GELUActivation()
#             (output_dense): QuantLinear(
#               in_features=3072, out_features=768, bias=True
#               (_input_quantizer): TensorQuantizer(4bit fake per-tensor amax=20.6923 calibrator=MaxCalibrator scale=1.0 quant)
#               (_weight_quantizer): TensorQuantizer(8bit fake axis=0 amax=[0.0956, 3.9316](768) calibrator=MaxCalibrator scale=1.0 quant)
#             )
#             (output_dropout): Dropout(p=0.1, inplace=False)
#           )
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (10): Wav2Vec2EncoderLayer(
#           (attention): Wav2Vec2Attention(
#             (k_proj): QuantLinear(
#               in_features=768, out_features=768, bias=True
#               (_input_quantizer): TensorQuantizer(4bit fake per-tensor amax=4.7260 calibrator=MaxCalibrator scale=1.0 quant)
#               (_weight_quantizer): TensorQuantizer(8bit fake axis=0 amax=[0.2052, 1.0547](768) calibrator=MaxCalibrator scale=1.0 quant)
#             )
#             (v_proj): QuantLinear(
#               in_features=768, out_features=768, bias=True
#               (_input_quantizer): TensorQuantizer(4bit fake per-tensor amax=4.7260 calibrator=MaxCalibrator scale=1.0 quant)
#               (_weight_quantizer): TensorQuantizer(8bit fake axis=0 amax=[0.1298, 0.3694](768) calibrator=MaxCalibrator scale=1.0 quant)
#             )
#             (q_proj): QuantLinear(
#               in_features=768, out_features=768, bias=True
#               (_input_quantizer): TensorQuantizer(4bit fake per-tensor amax=4.7260 calibrator=MaxCalibrator scale=1.0 quant)
#               (_weight_quantizer): TensorQuantizer(8bit fake axis=0 amax=[0.2095, 0.9751](768) calibrator=MaxCalibrator scale=1.0 quant)
#             )
#             (out_proj): QuantLinear(
#               in_features=768, out_features=768, bias=True
#               (_input_quantizer): TensorQuantizer(4bit fake per-tensor amax=4.3122 calibrator=MaxCalibrator scale=1.0 quant)
#               (_weight_quantizer): TensorQuantizer(8bit fake axis=0 amax=[0.0556, 0.4287](768) calibrator=MaxCalibrator scale=1.0 quant)
#             )
#           )
#           (dropout): Dropout(p=0.1, inplace=False)
#           (layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (feed_forward): Wav2Vec2FeedForward(
#             (intermediate_dropout): Dropout(p=0.0, inplace=False)
#             (intermediate_dense): QuantLinear(
#               in_features=768, out_features=3072, bias=True
#               (_input_quantizer): TensorQuantizer(4bit fake per-tensor amax=10.1520 calibrator=MaxCalibrator scale=1.0 quant)
#               (_weight_quantizer): TensorQuantizer(8bit fake axis=0 amax=[0.1272, 1.2715](3072) calibrator=MaxCalibrator scale=1.0 quant)
#             )
#             (intermediate_act_fn): GELUActivation()
#             (output_dense): QuantLinear(
#               in_features=3072, out_features=768, bias=True
#               (_input_quantizer): TensorQuantizer(4bit fake per-tensor amax=45.4471 calibrator=MaxCalibrator scale=1.0 quant)
#               (_weight_quantizer): TensorQuantizer(8bit fake axis=0 amax=[0.1192, 5.7695](768) calibrator=MaxCalibrator scale=1.0 quant)
#             )
#             (output_dropout): Dropout(p=0.1, inplace=False)
#           )
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (11): Wav2Vec2EncoderLayer(
#           (attention): Wav2Vec2Attention(
#             (k_proj): QuantLinear(
#               in_features=768, out_features=768, bias=True
#               (_input_quantizer): TensorQuantizer(4bit fake per-tensor amax=3.1913 calibrator=MaxCalibrator scale=1.0 quant)
#               (_weight_quantizer): TensorQuantizer(8bit fake axis=0 amax=[0.2256, 1.0381](768) calibrator=MaxCalibrator scale=1.0 quant)
#             )
#             (v_proj): QuantLinear(
#               in_features=768, out_features=768, bias=True
#               (_input_quantizer): TensorQuantizer(4bit fake per-tensor amax=3.1913 calibrator=MaxCalibrator scale=1.0 quant)
#               (_weight_quantizer): TensorQuantizer(8bit fake axis=0 amax=[0.0931, 0.3286](768) calibrator=MaxCalibrator scale=1.0 quant)
#             )
#             (q_proj): QuantLinear(
#               in_features=768, out_features=768, bias=True
#               (_input_quantizer): TensorQuantizer(4bit fake per-tensor amax=3.1913 calibrator=MaxCalibrator scale=1.0 quant)
#               (_weight_quantizer): TensorQuantizer(8bit fake axis=0 amax=[0.2212, 0.9106](768) calibrator=MaxCalibrator scale=1.0 quant)
#             )
#             (out_proj): QuantLinear(
#               in_features=768, out_features=768, bias=True
#               (_input_quantizer): TensorQuantizer(4bit fake per-tensor amax=1.9225 calibrator=MaxCalibrator scale=1.0 quant)
#               (_weight_quantizer): TensorQuantizer(8bit fake axis=0 amax=[0.0471, 0.3879](768) calibrator=MaxCalibrator scale=1.0 quant)
#             )
#           )
#           (dropout): Dropout(p=0.1, inplace=False)
#           (layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (feed_forward): Wav2Vec2FeedForward(
#             (intermediate_dropout): Dropout(p=0.0, inplace=False)
#             (intermediate_dense): QuantLinear(
#               in_features=768, out_features=3072, bias=True
#               (_input_quantizer): TensorQuantizer(4bit fake per-tensor amax=5.7620 calibrator=MaxCalibrator scale=1.0 quant)
#               (_weight_quantizer): TensorQuantizer(8bit fake axis=0 amax=[0.1136, 0.4573](3072) calibrator=MaxCalibrator scale=1.0 quant)
#             )
#             (intermediate_act_fn): GELUActivation()
#             (output_dense): QuantLinear(
#               in_features=3072, out_features=768, bias=True
#               (_input_quantizer): TensorQuantizer(4bit fake per-tensor amax=2.3017 calibrator=MaxCalibrator scale=1.0 quant)
#               (_weight_quantizer): TensorQuantizer(8bit fake axis=0 amax=[0.0502, 0.6333](768) calibrator=MaxCalibrator scale=1.0 quant)
#             )
#             (output_dropout): Dropout(p=0.1, inplace=False)
#           )
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#     )
#   )
#   (dropout): Dropout(p=0.0, inplace=False)
#   (lm_head): QuantLinear(
#     in_features=768, out_features=32, bias=True
#     (_input_quantizer): TensorQuantizer(4bit fake per-tensor amax=6.5119 calibrator=MaxCalibrator scale=1.0 quant)
#     (_weight_quantizer): TensorQuantizer(8bit fake axis=0 amax=[0.0576, 0.0912](32) calibrator=MaxCalibrator scale=1.0 quant)
#   )
# )

# %% [markdown]
# Once calibration is finished, we perform quantization and export the model to onnx format

# %%
input_size = 100000
AUDIO_MAXLEN = input_size
dummy_input = torch.randn(1, input_size, requires_grad=True).cuda()

# %%
torch.onnx.export(model_quantized,
         dummy_input,
         "asr3.onnx",
         export_params=True,
         opset_version=10,
         do_constant_folding=True,
         input_names = ['modelInput'],
         output_names = ['modelOutput'],
         dynamic_axes={'modelInput' : {0 : 'batch_size'},
         'modelOutput' : {0 : 'batch_size'}}
)
# Out:
# /home/kmb85/.local/lib/python3.10/site-packages/pytorch_quantization/tensor_quant.py:257: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if amax.numel() == 1:
# /home/kmb85/.local/lib/python3.10/site-packages/pytorch_quantization/tensor_quant.py:260: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   axis = amax.shape.index(amax.numel())
# /home/kmb85/.local/lib/python3.10/site-packages/transformers/models/wav2vec2/modeling_wav2vec2.py:637: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if attn_weights.size() != (bsz * self.num_heads, tgt_len, src_len):
# /home/kmb85/.local/lib/python3.10/site-packages/transformers/models/wav2vec2/modeling_wav2vec2.py:674: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if attn_output.size() != (bsz * self.num_heads, tgt_len, self.head_dim):

# %% [markdown]
# ### Base vs Quantized Model Inference Time

# %%
# !pip install onnxruntime-gpu

# %%
import onnxruntime as ort
ort.get_device()
# Out:
# 'GPU'

# %%
import numpy as np
import tensorrt
ort_sess = ort.InferenceSession('asr3.onnx', providers=['TensorrtExecutionProvider'])
# Out:
# 2023-12-09 20:14:56.927360566 [W:onnxruntime:Default, tensorrt_execution_provider.h:77 log] [2023-12-09 20:14:56 WARNING] onnx2trt_utils.cpp:374: Your ONNX model has been generated with INT64 weights, while TensorRT does not natively support INT64. Attempting to cast down to INT32.
# 2023-12-09 20:15:04.278075481 [W:onnxruntime:Default, tensorrt_execution_provider.h:77 log] [2023-12-09 20:15:04 WARNING] onnx2trt_utils.cpp:374: Your ONNX model has been generated with INT64 weights, while TensorRT does not natively support INT64. Attempting to cast down to INT32.

# %%
X = np.asarray(torch.tensor(timit["test"][4:5]["input_values"]))
X_ortvalue = ort.OrtValue.ortvalue_from_numpy(X, 'cuda', 0)

# %%
import time

input_size = 100000
AUDIO_MAXLEN = input_size
dummy_input = torch.randn(1, input_size, requires_grad=True).cuda()

starttime = time.time()
with torch.no_grad():
    model(dummy_input)

print(f'Base Model inference time {time.time() - starttime}')
# Out:
# 0.6450047492980957

# %%
input_size = 100000
AUDIO_MAXLEN = input_size
dummy_input = torch.randn(1, input_size, requires_grad=True).detach().numpy()
X_ortvalue = ort.OrtValue.ortvalue_from_numpy(dummy_input, 'cuda', 0)

# %%
import time

starttime = time.time()
with torch.no_grad():
    ort_sess.run(None, {"modelInput": X_ortvalue})

print(f'Quantized Model inference time {time.time() - starttime}')
# Out:
# 0.004495859146118164

# %% [markdown]
# Finally, we visualise the inference time

# %%
import matplotlib.pyplot as plt

models = ['Base Wav2Vec', 'Quantized Wav2Vec']
inference_times = [0.6450047492980957, 0.004495859146118164]

plt.figure(figsize=(10, 6))
plt.bar(models, inference_times, color=['blue', 'green'])
plt.xlabel('Model')
plt.ylabel('Inference Time (seconds)')
plt.title('Inference Time Comparison: Base Wav2Vec Model vs Quantized Wav2Vec Model')
plt.ylim(0, max(inference_times) * 1.1)
plt.show()

# %% [markdown]
# We adjust the graph to use log scale to make the quantized Wav2Vec model time more visible

# %%
plt.figure(figsize=(10, 6))
plt.bar(models, inference_times, color=['blue', 'green'])
plt.xlabel('Model')
plt.ylabel('Inference Time (seconds, log scale)')
plt.title('Inference Time Comparison: Base Wav2Vec Model vs Quantized Wav2Vec Model')
plt.yscale('log')
plt.ylim(0.001, 1)
plt.show()

# %% [markdown]
# Finally, we calculate how many times the quantized model is faster than the base model

# %%
base_model_time = 0.6450047492980957
quantized_model_time = 0.004495859146118164

speedup_ratio = base_model_time / quantized_model_time
print(f'Quantized wav2vec2 is {round(speedup_ratio)} times faster than base wav2vec2')
# Out:
# Quantized wav2vec2 is 143 times faster than base wav2vec2
